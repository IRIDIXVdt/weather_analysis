# %% [markdown]
# # Loading data into Pandas

# %%
import pandas as pd
df = pd.read_csv('data/climate_data.csv')
# print(df.head(3))

# read txt
# df = pd.read_csv('data.txt', delimiter='\t')

# %% [markdown]
# # Reading Data in Pandas

# %%
# Read Headers
# print(df.columns)

# Read each Column
# print(df[['Date','Minimum pressure']])

# Read each Row
# print(df.iloc[1:4])
df.loc[df['Minimum pressure']==29.596]

# Read specific location
# print(df.iloc[2,1])
# Out:
#             Date  Average temperature (°F)  Average humidity (%)  \
# 0     2009-01-01                      37.8                  35.0
# 811   2011-06-23                      59.1                  54.0
# 1127  2012-08-02                      67.7                  42.0
# 1467  2013-08-06                      67.0                  33.0
# 1862  2014-09-29                      48.4                  79.0
#
#       Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                      12.7                    29.7                     26.4
# 811                    39.9                    29.7                      2.4
# 1127                   42.7                    29.7                      3.8
# 1467                   35.8                    29.7                      6.9
# 1862                   42.1                    29.7                      2.6
#
#       Average gustspeed (mph)  Average direction (°deg)  \
# ...

# %% [markdown]
# # Describing Data

# %%
df.describe()
# df.sort_values('Maximum pressure')
# df.sort_values(['Maximum pressure','Minimum pressure'],ascending=[1,0])
# Out:
#        Average temperature (°F)  Average humidity (%)  Average dewpoint (°F)  \
# count               3902.000000           3902.000000            3902.000000
# mean                  44.670733             48.878011              23.127037
# std                   15.326793             17.438153              14.634088
# min                  -12.100000              9.000000             -22.200000
# 25%                   33.700000             36.000000              12.100000
# 50%                   45.100000             47.000000              22.500000
# 75%                   58.000000             61.000000              35.400000
# max                   76.300000             94.000000              55.100000
#
#        Average barometer (in)  Average windspeed (mph)  \
# count             3902.000000              3902.000000
# mean                29.881420                 5.758893
# std                  0.250395                 4.022485
# ...

# %% [markdown]
# # Making Changes to Data

# %%
df['Total']=df['Maximum pressure']+df['Minimum pressure']
df.head(5)
# Out:
#          Date  Average temperature (°F)  Average humidity (%)  \
# 0  2009-01-01                      37.8                  35.0
# 1  2009-01-02                      43.2                  32.0
# 2  2009-01-03                      25.7                  60.0
# 3  2009-01-04                       9.3                  67.0
# 4  2009-01-05                      23.5                  30.0
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# ...

# %% [markdown]
# # Saving Changes to Data

# %%
df.to_csv('data/modified.csv',index=False)
